# %% [markdown]
# # Tutorial 4: Handling the box in Molecular Xtal
#
# Source code: https://github.com/qzhu2017/PyXtal
#
# Created by Qiang Zhu (2021/07/02)
#
# Last updated: 2021/07/02

# %% [markdown]
# ## Preparation
#
# - git clone the most recent copy of pyxtal
# - `conda install -c conda-forge rdkit==2020.09.5`
# - `python setup.py install`
# - download the cif file from https://www.ccdc.cam.ac.uk/structures/Search?Ccdcid=ABAVUW
# - name the cif file as `ABAVUW.cif`
# - draw smiles: http://www.cheminfo.org/flavor/malaria/Utilities/SMILES_generator___checker/index.html

# %%
from pyxtal import pyxtal
s = pyxtal(molecular=True)
s.from_seed('ABAVUW.cif', ["CC(C)(C)C1=CC(=C(C(=C1)OC)O)C=NO.smi"])
print(s)
# Out:
# ------Crystal from Seed------
# Dimension: 3
# Composition: [CC(C)(C)C1=CC(=C(C(=C1)OC)O)C=NO]4
# Group: P212121 (19)
# orthorhombic lattice:   9.6192  10.6124  11.8069  90.0000  90.0000  90.0000
# Wyckoff sites:
# 	H17C12N1O3 @ [ 0.9353  0.3662  0.4499]  WP:  4a, Site symmetry 1 ==> Euler:   0.00   0.00   0.00

# %%
# view the site
site = s.mol_sites[0]
site.show(box=True, axis=False)
# Out:
# <div id="3dmolviewer_1625286802862557"  style="position: relative; width: 400px; height: 300px">
#         <p id="3dmolwarning_1625286802862557" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1625286802862557 = null;
# var warn = document.getElementById("3dmolwarning_1625286802862557");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1625286802862557 = $3Dmol.createViewer($("#3dmolviewer_1625286802862557"),{backgroundColor:"white"});
# 	viewer_1625286802862557.addModel("33\nH17 C12 N1 O3\nC 7.215362 4.028679 2.067742\nC 8.398908 4.804021 2.647107\nC 8.084938 6.299945 2.513571\nC 9.650943 4.486923 1.820860\nC 8.686041 4.419958 4.098647\nC 8.273762 3.206537 4.633382\nC 8.650450 2.807404 5.929897\nC 9.432780 3.655653 6.711278\nC 9.821396 4.894227 6.190830\nC 9.474239 5.255473 4.904704\nO 10.574771 5.650042 7.056158\nC 10.896630 6.967996 6.663814\nO 9.840923 3.351820 7.973200\nC 8.225955 1.499850 6.410792\nN 8.597449 1.071003 7.559840\nO 8.118893 -0.221162 7.810855\nH 7.073960 4.296961 1.135824\nH 6.410235 4.223735 2.590434\nH 7.404860 3.068045 2.105170\nH 7.840610 6.501156 1.585667\nH 7.338488 6.530871 3.105215\nH 8.874674 6.822712 2.763995\nH 9.502808 4.750110 0.889060\nH 9.835632 3.525439 1.863129\nH 10.414708 4.982522 2.181915\nH 7.725180 2.631875 4.112343\nH 9.775031 6.087273 4.557463\nH 10.072264 7.457333 6.457194\nH 11.468972 6.941571 5.869210\nH 11.369894 7.419129 7.393481\nH 9.551866 2.578813 8.159749\nH 7.666502 0.958300 5.865668\nH 8.474515 -0.424496 8.548196","xyz");
# 	viewer_1625286802862557.addBox({"center": {"x": 8.996465015999998, "y": 3.8861481232500017, "z": 5.312042379000002}, "dimensions": {"w": {"x": 0.19999458076351112, "y": -5.956525993502817, "z": 7.606848086136692}, "h": {"x": -3.965007710937071, "y": -5.152584241762804, "z": -3.9304744325563132}, "d": {"x": 3.1873928998013743, "y": -1.4955237741430727, "z": -1.2548676446826423}}, "color": "magenta", "alpha": 0.5});
# 	viewer_1625286802862557.addModel("33\nH17 C12 N1 O3\nC 7.213438 6.583721 7.971192\nC 6.029892 5.808379 8.550557\nC 6.343862 4.312455 8.417021\nC 4.777857 6.125477 7.724310\nC 5.742759 6.192442 10.002097\nC 6.155038 7.405863 10.536832\nC 5.778350 7.804996 11.833347\nC 4.996020 6.956747 12.614728\nC 4.607404 5.718173 12.094280\nC 4.954561 5.356927 10.808154\nO 3.854029 4.962358 12.959608\nC 3.532170 3.644404 12.567264\nO 4.587877 7.260580 13.876650\nC 6.202845 9.112550 12.314242\nN 5.831351 9.541397 13.463290\nO 6.309907 10.833562 13.714305\nH 7.354840 6.315439 7.039274\nH 8.018565 6.388665 8.493884\nH 7.023940 7.544355 8.008620\nH 6.588190 4.111244 7.489117\nH 7.090312 4.081529 9.008665\nH 5.554126 3.789688 8.667445\nH 4.925992 5.862290 6.792510\nH 4.593168 7.086961 7.766579\nH 4.014092 5.629878 8.085365\nH 6.703620 7.980525 10.015793\nH 4.653769 4.525127 10.460913\nH 4.356536 3.155067 12.360644\nH 2.959828 3.670829 11.772660\nH 3.058906 3.193271 13.296931\nH 4.876934 8.033587 14.063199\nH 6.762298 9.654100 11.769118\nH 5.954285 11.036896 14.451646","xyz");
# 	viewer_1625286802862557.addBox({"center": {"x": 5.432334983999996, "y": 6.726251876749997, "z": 11.215492379}, "dimensions": {"w": {"x": -0.1999945807635096, "y": 5.956525993502818, "z": 7.606848086136689}, "h": {"x": -3.965007710937071, "y": -5.152584241762803, "z": 3.9304744325563155}, "d": {"x": 3.187392899801375, "y": -1.4955237741430727, "z": 1.2548676446826421}}, "color": "magenta", "alpha": 0.5});
# 	viewer_1625286802862557.addModel("33\nH17 C12 N1 O3\nC 2.403838 9.334879 3.835708\nC 1.220292 10.110221 3.256343\nC 1.534262 11.606145 3.389879\nC -0.031743 9.793123 4.082590\nC 0.933159 9.726158 1.804803\nC 1.345438 8.512737 1.270068\nC 0.968750 8.113604 -0.026447\nC 0.186420 8.961853 -0.807828\nC -0.202196 10.200427 -0.287380\nC 0.144961 10.561673 0.998746\nO -0.955571 10.956242 -1.152708\nC -1.277430 12.274196 -0.760364\nO -0.221723 8.658020 -2.069750\nC 1.393245 6.806050 -0.507342\nN 1.021751 6.377203 -1.656390\nO 1.500307 5.085038 -1.907405\nH 2.545240 9.603161 4.767626\nH 3.208965 9.529935 3.313016\nH 2.214340 8.374245 3.798280\nH 1.778590 11.807356 4.317783\nH 2.280712 11.837071 2.798235\nH 0.744526 12.128912 3.139455\nH 0.116392 10.056310 5.014390\nH -0.216432 8.831639 4.040321\nH -0.795508 10.288722 3.721535\nH 1.894020 7.938075 1.791107\nH -0.155831 11.393473 1.345987\nH -0.453064 12.763533 -0.553744\nH -1.849772 12.247771 0.034240\nH -1.750694 12.725329 -1.490031\nH 0.067334 7.885013 -2.256299\nH 1.952698 6.264500 0.037782\nH 1.144685 4.881704 -2.644746","xyz");
# 	viewer_1625286802862557.addBox({"center": {"x": 0.6227349839999986, "y": 9.192348123250003, "z": 0.5914076210000001}, "dimensions": {"w": {"x": -0.19999458076350973, "y": -5.95652599350282, "z": -7.606848086136692}, "h": {"x": -3.965007710937071, "y": 5.152584241762803, "z": -3.9304744325563146}, "d": {"x": 3.1873928998013747, "y": 1.495523774143073, "z": -1.2548676446826423}}, "color": "magenta", "alpha": 0.5});
# 	viewer_1625286802862557.addModel("33\nH17 C12 N1 O3\nC 2.405762 1.277521 9.739158\nC 3.589308 0.502179 9.159793\nC 3.275338 -0.993745 9.293329\nC 4.841343 0.819277 9.986040\nC 3.876441 0.886242 7.708253\nC 3.464162 2.099663 7.173518\nC 3.840850 2.498796 5.877003\nC 4.623180 1.650547 5.095622\nC 5.011796 0.411973 5.616070\nC 4.664639 0.050727 6.902196\nO 5.765171 -0.343842 4.750742\nC 6.087030 -1.661796 5.143086\nO 5.031323 1.954380 3.833700\nC 3.416355 3.806350 5.396108\nN 3.787849 4.235197 4.247060\nO 3.309293 5.527362 3.996045\nH 2.264360 1.009239 10.671076\nH 1.600635 1.082465 9.216466\nH 2.595260 2.238155 9.701730\nH 3.031010 -1.194956 10.221233\nH 2.528888 -1.224671 8.701685\nH 4.065074 -1.516512 9.042905\nH 4.693208 0.556090 10.917840\nH 5.026032 1.780761 9.943771\nH 5.605108 0.323678 9.624985\nH 2.915580 2.674325 7.694557\nH 4.965431 -0.781073 7.249437\nH 5.262664 -2.151133 5.349706\nH 6.659372 -1.635371 5.937690\nH 6.560294 -2.112929 4.413419\nH 4.742266 2.727387 3.647151\nH 2.856902 4.347900 5.941232\nH 3.664915 5.730696 3.258704","xyz");
# 	viewer_1625286802862557.addBox({"center": {"x": 4.186865016, "y": 1.4200518767499979, "z": 6.494857620999999}, "dimensions": {"w": {"x": 0.19999458076351007, "y": 5.956525993502818, "z": -7.606848086136694}, "h": {"x": -3.965007710937072, "y": 5.152584241762803, "z": 3.930474432556314}, "d": {"x": 3.1873928998013747, "y": 1.4955237741430736, "z": 1.2548676446826426}}, "color": "magenta", "alpha": 0.5});
# 	viewer_1625286802862557.addLine({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 9.619199999999998, "y": 5.890061245179108e-16, "z": 5.890061245179108e-16}});
# 	viewer_1625286802862557.addLine({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0.0, "y": 10.612399999999997, "z": 6.498220845635684e-16}});
# 	viewer_1625286802862557.addLine({"start": {"x": 0, "y": 0, "z": 0}, "end": {"x": 0.0, "y": 0.0, "z": 11.8069}});
# 	viewer_1625286802862557.addLine({"start": {"x": 9.619199999999998, "y": 5.890061245179108e-16, "z": 5.890061245179108e-16}, "end": {"x": 9.619199999999998, "y": 10.612399999999997, "z": 1.2388282090814791e-15}});
# 	viewer_1625286802862557.addLine({"start": {"x": 9.619199999999998, "y": 5.890061245179108e-16, "z": 5.890061245179108e-16}, "end": {"x": 9.619199999999998, "y": 5.890061245179108e-16, "z": 11.8069}});

# %%
# view the first molecule within the box to check the box is okay
site.show_molecule_in_box()
# Out:
# <div id="3dmolviewer_1625286802933892"  style="position: relative; width: 400px; height: 300px">
#         <p id="3dmolwarning_1625286802933892" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1625286802933892 = null;
# var warn = document.getElementById("3dmolwarning_1625286802933892");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1625286802933892 = $3Dmol.createViewer($("#3dmolviewer_1625286802933892"),{backgroundColor:"white"});
# 	viewer_1625286802933892.addModels("33\nH17 C12 N1 O3\nC 7.215362 4.028679 2.067742\nC 8.398908 4.804021 2.647107\nC 8.084938 6.299945 2.513571\nC 9.650943 4.486923 1.820860\nC 8.686041 4.419958 4.098647\nC 8.273762 3.206537 4.633382\nC 8.650450 2.807404 5.929897\nC 9.432780 3.655653 6.711278\nC 9.821396 4.894227 6.190830\nC 9.474239 5.255473 4.904704\nO 10.574771 5.650042 7.056158\nC 10.896630 6.967996 6.663814\nO 9.840923 3.351820 7.973200\nC 8.225955 1.499850 6.410792\nN 8.597449 1.071003 7.559840\nO 8.118893 -0.221162 7.810855\nH 7.073960 4.296961 1.135824\nH 6.410235 4.223735 2.590434\nH 7.404860 3.068045 2.105170\nH 7.840610 6.501156 1.585667\nH 7.338488 6.530871 3.105215\nH 8.874674 6.822712 2.763995\nH 9.502808 4.750110 0.889060\nH 9.835632 3.525439 1.863129\nH 10.414708 4.982522 2.181915\nH 7.725180 2.631875 4.112343\nH 9.775031 6.087273 4.557463\nH 10.072264 7.457333 6.457194\nH 11.468972 6.941571 5.869210\nH 11.369894 7.419129 7.393481\nH 9.551866 2.578813 8.159749\nH 7.666502 0.958300 5.865668\nH 8.474515 -0.424496 8.548196\n","xyz");
# 	viewer_1625286802933892.addBox({"center": {"x": 8.996465015999998, "y": 3.8861481232500017, "z": 5.312042379000002}, "dimensions": {"w": {"x": 0.19999458076351112, "y": -5.956525993502817, "z": 7.606848086136692}, "h": {"x": -3.965007710937071, "y": -5.152584241762804, "z": -3.9304744325563132}, "d": {"x": 3.1873928998013743, "y": -1.4955237741430727, "z": -1.2548676446826423}}, "color": "magenta", "alpha": 0.5});
# 	viewer_1625286802933892.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_1625286802933892.zoomTo();
# viewer_1625286802933892.render();
# });
# </script>

# %%
# Here is the routine to get the box coordinates for each molecule
for id in range(site.wp.multiplicity):
    mol = site.get_mol_object(id)
    #print(id, site.molecule.get_box(padding=0))
    cell, pt, c = site.molecule.get_box_coordinates(mol.cart_coords)
    print(c)
# Out:
# [8.99646502 3.88614812 5.31204238]
# [ 5.43233498  6.72625188 11.21549238]
# [0.62273498 9.19234812 0.59140762]
# [4.18686502 1.42005188 6.49485762]

# %%
#here is the cell matrix
s.lattice.matrix
# Out:
# array([[9.61920000e+00, 5.89006125e-16, 5.89006125e-16],
#        [0.00000000e+00, 1.06124000e+01, 6.49822085e-16],
#        [0.00000000e+00, 0.00000000e+00, 1.18069000e+01]])

# %%
site.molecule.get_center(mol.cart_coords, geometry=True)
# Out:
# array([4.12202541, 1.04772366, 7.1348882 ])
