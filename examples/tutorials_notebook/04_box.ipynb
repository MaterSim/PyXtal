# %% [markdown]
# # Tutorial 4: Handling the box in Molecular Xtal
#
# Source code: https://github.com/qzhu2017/PyXtal
#
# Created by Qiang Zhu (2021/07/02)
#
# Last updated: 2021/07/02

# %% [markdown]
# ## Preparation
#
# - git clone the most recent copy of pyxtal
# - `conda install -c conda-forge rdkit==2020.09.5`
# - `python setup.py install`
# - download the cif file from https://www.ccdc.cam.ac.uk/structures/Search?Ccdcid=ABAVUW
# - name the cif file as `ABAVUW.cif`
# - draw smiles: http://www.cheminfo.org/flavor/malaria/Utilities/SMILES_generator___checker/index.html

# %%
from pyxtal import pyxtal
s = pyxtal(molecular=True)
s.from_seed('ABAVUW.cif', ["CC(C)(C)C1=CC(=C(C(=C1)OC)O)C=NO.smi"])
print(s)
# Out:
# RDKit WARNING: [10:07:45] Enabling RDKit 2019.09.3 jupyter extensions
# ------Crystal from Seed------
# Dimension: 3
# Composition: [CC(C)(C)C1=CC(=C(C(=C1)OC)O)C=NO]4
# Group: P212121 (19)
# orthorhombic lattice:   9.6192  10.6124  11.8069  90.0000  90.0000  90.0000
# Wyckoff sites:
# 	H17C12N1O3 @ [ 0.9353  0.3662  0.4499]  WP:  4a, Site symmetry 1 ==> Euler:   0.00   0.00   0.00

# %%
# view the site
site = s.mol_sites[0]
site.show(box=True, axis=False)
# Out:
# <div id="3dmolviewer_16252456661589491"  style="position: relative; width: 400px; height: 300px">
#         <p id="3dmolwarning_16252456661589491" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16252456661589491 = null;
# var warn = document.getElementById("3dmolwarning_16252456661589491");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16252456661589491 = $3Dmol.createViewer($("#3dmolviewer_16252456661589491"),{backgroundColor:"white"});
# viewer_16252456661589491.zoomTo();
# 	viewer_16252456661589491.addModel("33\nH17 C12 N1 O3\nC 7.215362 4.028679 2.067742\nC 8.398908 4.804021 2.647107\nC 8.084938 6.299945 2.513571\nC 9.650943 4.486923 1.820860\nC 8.686041 4.419958 4.098647\nC 8.273762 3.206537 4.633382\nC 8.650450 2.807404 5.929897\nC 9.432780 3.655653 6.711278\nC 9.821396 4.894227 6.190830\nC 9.474239 5.255473 4.904704\nO 10.574771 5.650042 7.056158\nC 10.896630 6.967996 6.663814\nO 9.840923 3.351820 7.973200\nC 8.225955 1.499850 6.410792\nN 8.597449 1.071003 7.559840\nO 8.118893 -0.221162 7.810855\nH 7.073960 4.296961 1.135824\nH 6.410235 4.223735 2.590434\nH 7.404860 3.068045 2.105170\nH 7.840610 6.501156 1.585667\nH 7.338488 6.530871 3.105215\nH 8.874674 6.822712 2.763995\nH 9.502808 4.750110 0.889060\nH 9.835632 3.525439 1.863129\nH 10.414708 4.982522 2.181915\nH 7.725180 2.631875 4.112343\nH 9.775031 6.087273 4.557463\nH 10.072264 7.457333 6.457194\nH 11.468972 6.941571 5.869210\nH 11.369894 7.419129 7.393481\nH 9.551866 2.578813 8.159749\nH 7.666502 0.958300 5.865668\nH 8.474515 -0.424496 8.548196","xyz");
# 	viewer_16252456661589491.addLine({"start": {"x": 9.220435529004273, "y": 10.560793343249806, "z": 3.4612587926420457}, "end": {"x": 9.420430109767784, "y": 4.604267349746987, "z": 11.068106878778735}});
# 	viewer_16252456661589491.addLine({"start": {"x": 9.420430109767784, "y": 4.604267349746987, "z": 11.068106878778735}, "end": {"x": 5.45542239883071, "y": -0.5483168920158183, "z": 7.137632446222419}});
# 	viewer_16252456661589491.addLine({"start": {"x": 5
# 	viewer_16252456661899369.addLine({"start": {"x": 9.220435529004273, "y": 10.560793343249806, "z": 3.4612587926420457}, "end": {"x": 5.255427818067201, "y": 5.408209101487001, "z": -0.46921563991427195}});
# 	viewer_16252456661899369.addLine({"start": {"x": 9.220435529004273, "y": 10.560793343249806, "z": 3.4612587926420457}, "end": {"x": 12.40782842880565, "y": 9.065269569106732, "z": 2.206391147959403}});
# 	viewer_16252456661899369.addLine({"start": {"x": 9.420430109767784, "y": 4.604267349746987, "z": 11.068106878778735}, "end": {"x": 12.60782300956916, "y": 3.108743575603914, "z": 9.813239234096095}});
# 	viewer_16252456661899369.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_16252456661899369.zoomTo();
# viewer_16252456661899369.render();
# });
# </script>

# %%
# Here is the routine to get the box coordinates for each molecule
for id in range(site.wp.multiplicity):
    mol = site.get_mol_object(id)
    print(id, site.molecule.get_box(padding=0))
    print(site.molecule.get_box_coordinates(mol.cart_coords))
# Out:
# 0 l:   9.66, w:   7.60, d:   3.74
# [[ 9.22043553 10.56079334  3.46125879]
#  [ 9.42043011  4.60426735 11.06810688]
#  [ 5.4554224  -0.54831689  7.13763245]
#  [ 5.25542782  5.4082091  -0.46921564]
#  [ 8.44282072  3.91268533 -1.72408328]
#  [12.40782843  9.06526957  2.20639115]
#  [12.60782301  3.10874358  9.81323923]
#  [ 8.6428153  -2.04384067  5.8827648 ]]
# 1 l:   9.66, w:   7.60, d:   3.74
# [[ 5.98597928  6.69971467  4.17936672]
#  [ 5.7859847  12.65624067 11.7862148 ]
#  [ 1.82097699  7.50365642 15.71668923]
#  [ 2.02097157  1.54713043  8.10984115]
#  [ 5.20836447  0.05160666  9.36470879]
#  [ 9.17337218  5.2041909   5.43423436]
#  [ 8.9733776  11.16071689 13.04108245]
#  [ 5.00836989  6.00813265 16.97155688]]
# 2 l:   9.66, w:   7.60, d:   3.74
# [[ 1.17637928  9.21888533  7.62753328]
#  [ 0.9763847   3.26235933  0.0206852 ]
#  [-2.98862301  8.41494358 -3.90978923]
#  [-2.78862843 14.37146957  3.69705885]
#  [ 0.39876447 15.86699334  2.44219121]
#  [ 4.36377218 10.7144091   6.37266564]
#  [ 4.1637776   4.75788311 -1.23418245]
#  [ 0.19876989  9.91046735 -5.16465688]]
# 3 l:   9.66, w:   7.60, d:   3.74
# [[ 4.41083553 -5.25459334  8.34564121]
#  [ 4.61083011  0.70193265  0.73879312]
#  [ 0.6458224   5.85451689  4.66926755]
#  [ 0.44582782 -0.1020091  12.27611564]
#  [ 3.63322072  1.39351467 13.53098328]
#  [ 7.59822843 -3.75906957  9.60050885]
#  [ 7.79822301  2.19745642  1.99366077]
#  [ 3.8332153   7.35004067  5.9241352 ]]

# %%
#here is the cell matrix
s.lattice.matrix
# Out:
# array([[9.61920000e+00, 5.89006125e-16, 5.89006125e-16],
#        [0.00000000e+00, 1.06124000e+01, 6.49822085e-16],
#        [0.00000000e+00, 0.00000000e+00, 1.18069000e+01]])
