# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Wyckoff.csv',delimiter=':')

# %%
df
# Out:
#         1        P 1    Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0     NaN          NaN         1.0          a          1        (x,y,z)
# 1       2       P -1           NaN        NaN        NaN            NaN
# 2     NaN          NaN         2.0          i          1        (x,y,z)
# 3     NaN          NaN         1.0          h         -1  (1/2,1/2,1/2)
# 4     NaN          NaN         1.0          g         -1    (0,1/2,1/2)
# 5     NaN          NaN         1.0          f         -1    (1/2,0,1/2)
# 6     NaN          NaN         1.0          e         -1    (1/2,1/2,0)
# 7     NaN          NaN         1.0          d         -1      (1/2,0,0)
# 8     NaN          NaN         1.0          c         -1      (0,1/2,0)
# 9     NaN          NaN         1.0          b         -1      (0,0,1/2)
# 10    NaN          NaN         1.0          a         -1        (0,0,0)
# 11      3      P 1 2 1         NaN        NaN        NaN            NaN
# ...
